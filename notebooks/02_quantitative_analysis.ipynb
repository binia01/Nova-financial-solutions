# %% [markdown]
# # Import Dependencies

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %% [markdown]
# # Import src packages

# %%
# Import the functions from your newly created modules
from src.stock_data_processing import load_and_prepare_data
from src.technical_analysis import add_technical_indicators
from src.stock_visualizer import plot_technical_analysis

# %% [markdown]
# ### Add file path

# %%
# Path to yfinance data
file_path = '../data/Data'

# %% [markdown]
# ### Data loading

# %%
# Use your module to handle all the low-level data loading details.
stock_data = load_and_prepare_data(file_path=file_path)
print("--- Raw Data Head ---")
print(stock_data.head())
# Out:
# Data loaded and prepared successfully!
# Loaded data for 6 stocks.
# --- Raw Data Head ---
#                Close      High       Low      Open      Volume Ticker
# Date
# 2009-01-02  2.721686  2.730385  2.554037  2.575630   746015200   AAPL
# 2009-01-05  2.836553  2.884539  2.780469  2.794266  1181608400   AAPL
# 2009-01-06  2.789767  2.914229  2.770872  2.877641  1289310400   AAPL
# 2009-01-07  2.729484  2.774170  2.706990  2.753477   753048800   AAPL
# 2009-01-08  2.780169  2.793666  2.700393  2.712090   673500800   AAPL

# %% [markdown]
# ### Technical Analysis

# %%
# Use your module to calculate all indicators.
analysis_data = add_technical_indicators(stock_data)
print("\n--- Data with Indicators Head ---")
print(analysis_data.head())
# Out:
# Calculating technical indicators...
# Technical indicators added successfully.
#
# --- Data with Indicators Head ---
#                Close      High       Low      Open     Volume    SMA_20  \
# Date
# 2009-03-16  2.861745  2.920827  2.824556  2.895035  797244000  2.716199
# 2009-03-17  2.988908  2.989807  2.851248  2.856347  786646000  2.723891
# 2009-03-18  3.044690  3.103472  2.990706  2.996404  796037200  2.734613
# 2009-03-19  3.047690  3.095075  3.006602  3.054588  500180800  2.751078
# 2009-03-20  3.046790  3.092377  3.016200  3.061785  695587200  2.766659
#
#               SMA_50     RSI_14      MACD  MACD_signal  MACD_hist Ticker
# Date
# 2009-03-16  2.733174  56.299129  0.017436    -0.004336   0.021772   AAPL
# 2009-03-17  2.738518  61.744864  0.034851     0.003501   0.031350   AAPL
# 2009-03-18  2.742681  63.871682  0.052548     0.013310   0.039237   AAPL
# 2009-03-19  2.747839  63.987651  0.066053     0.023859   0.042194   AAPL
# ...

# %% [markdown]
# # Visualization

# %%
# List of tickers to visualize
tickers = stock_data['Ticker'].unique()
print(tickers)
# Out:
# ['AAPL' 'AMZN' 'GOOG' 'META' 'MSFT' 'NVDA']

# %%
# Visualize each ticker separately

for ticker in tickers:
     print(f"\nVisualizing data for {ticker}...")
     plot_technical_analysis(analysis_data, ticker)
     print()
# Out:
# Visualizing data for AAPL...
# Visualizing data for AMZN...
# Visualizing data for GOOG...
# /home/bini/Documents/repos/Nova-financial-solutions/.venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Visualizing data for META...
# Visualizing data for MSFT...
# Visualizing data for NVDA...
